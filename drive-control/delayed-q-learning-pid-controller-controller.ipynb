# %%
import numpy as np
import numpy.typing as npt
import matplotlib.pyplot as plt
import math

# Generate the path
def gen_path(length: float, dt: float) -> tuple[float, np.ndarray, np.ndarray]:
    N = 50
    r0 = np.sqrt(np.random.uniform(0.0,50.0, (N,1)))
    r1 = np.random.uniform(0.0,6.2, (N,1))
    r2 = np.random.uniform(0.0,2.0, (N,1))/(r0*r0)
    t = np.reshape(np.linspace(0, length, int(length / dt)), (1,-1))
    x = np.sum(np.sin(t * r0 + r1) * r2, axis=0)
    x = (x-np.min(x))/(np.max(x)-np.min(x))
    t = t[0]
    return dt, t, x

# PID Controller
class PIDController:
    def __init__(self, kp=0.5, ki=0.5, kd=0.5):
        self.kp = kp
        self.ki = ki
        self.kd = kd
        self.prev_x = 0.0
        self.prev_tx = 0.0
        self.integral = 0.0

    def control(self, x, tx, dt):
        self.integral += (tx - x) * dt
        self.integral *= pow(0.5, dt)
        derivative = ((tx - self.prev_tx) - (x - self.prev_x)) / dt
        output = self.kp * (tx - x) + self.ki * self.integral + self.kd * derivative
        self.prev_x = x
        self.prev_tx = tx
        return output

class TheSystem:
    def __init__(self, mass: float, mu_s: float, mu_k: float, x=0.0, v=0.0) -> None:
        self.x = x
        self.v = v
        self.mass = mass
        self.mu_s = mu_s
        self.mu_k = mu_k
    def step(self, dt: float, force: float):
        force = force_response(force, self.v, self.mass, self.mu_k) * np.random.uniform(0.95,1.05)
        friction = 0.0
        g = 10
        if abs(self.v) > 0.001:
            friction = -abs(self.v)/self.v * self.mu_k * g
        else:
            friction = np.clip(-force, -self.mu_s * g, self.mu_s * g)

        a = (force + friction) / self.mass
        self.v += a / 2 * dt
        self.x += self.v * dt
        self.v += a / 2 * dt

def force_response(power: float, vel : float, mass: float, muKinetic: float):
    GRAVITY_ACCEL = 9.8
    linearTopSpeed = 2

    maxLinearVel = (4 - math.exp(1.45 - abs(np.clip(power,-1,1)))) / 4.0 * linearTopSpeed
    friction = GRAVITY_ACCEL * mass * muKinetic
    forceMag = 100 * math.exp((maxLinearVel - abs(vel)) / linearTopSpeed * 5.0)
    return np.sign(power) * forceMag

# Update PID parameters based on action
def update_pid_by_action(pid: PIDController, action: int, dt: float):
    R = 10.0
    if action == 0: # Idle
        pass
    elif action == 1:  # Increase KP
        pid.kp += 0.1 * dt * R
    elif action == 2:  # Decrease KP
        pid.kp -= 0.1 * dt * R
    elif action == 3:  # Increase KI
        pid.ki += 0.01 * dt * R
    elif action == 4:  # Decrease KI
        pid.ki -= 0.01 * dt * R
    elif action == 5:  # Increase KD
        pid.kd += 0.1 * dt * R
    elif action == 6:  # Decrease KD
        pid.kd -= 0.1 * dt * R


qtable = np.random.uniform(0.0,1.0,[11*11*3,6])
THR = 0.05

def get_state(system: TheSystem, target: (float, float), force: float):
    tx, tv = target
    n = 0
    ex = system.x - tx
    ev = system.v - tv

    return int(np.clip(round(ex/.1), -5, 5) + 11 * np.clip(round(ev/.1), -5, 5) + 11 * 11 * np.clip(round(force/.05), -1, 1))

def get_loss(system: TheSystem, target: (float, float)):
    tx, tv = target
    return abs(system.x-tx)+abs(system.v-tv)

# %%
qtable = np.random.uniform(0.0,1.0,[11*11*3,6])

# Q-learning parameters
alpha = -0.05  # Learning rate
gamma = 0.9  # Discount factor
epsilon = 0.01  # Epsilon-greedy exploration rate

# Q-learning function
def q_learning(qtable: npt.NDArray, episodes=1000):
    T = 10.0
    losses = []
    for episode in range(episodes):
        # Generate a path and reset the system
        dt, t, tx = gen_path(T, 0.1)
        print(len(t), t.shape)
        # system = TheSystem(mass=np.random.uniform(0.02,20.0))
        system = TheSystem(
            mass=np.random.uniform(0.01,50.0),
            mu_s=np.random.uniform(0.0,0.1)**2,
            mu_k=np.random.uniform(0.0,0.1)**2,
            x=tx[0], v=(tx[1]-tx[0])/dt,
        )
        pid = PIDController(np.random.uniform(0, 1),np.random.uniform(0, 1),np.random.uniform(0, 1))
        delayed_system_x = [system.x, system.x, system.x]

        total_loss = 0
        scheduled_loss_updates: list[tuple[int, int, float]] = []
        for step in range(len(t)):
            target = (tx[step], (tx[step]-tx[max(step-1,0)])/dt)
            delayed_system_x.append(system.x)
            power = pid.control(delayed_system_x.pop(0), target[0], dt)
            # Get the current state
            state = get_state(system, target, power)

            # Choose an action using epsilon-greedy policy
            if np.random.uniform(0, 1) < epsilon:
                action = np.random.randint(0, qtable.shape[1])
            else:
                action = np.argmax(qtable[state])

            # Update PID parameters based on the chosen action
            update_pid_by_action(pid, action, dt)
            new_kp = np.clip(pid.kp, 0.0, 200.0)
            new_ki = np.clip(pid.ki, 0.0, 200.0)
            new_kd = np.clip(pid.kd, 0.0, 200.0)
            total_overshoot = abs(new_kp-pid.kp) + abs(new_ki-pid.ki) + abs(new_kd-pid.kd)
            pid.kp = new_kp
            pid.ki = new_ki
            pid.kd = new_kd

            # Perform the action and get the next state
            system.step(dt, power)

            # Calculate the reward (negative of the loss)
            loss = get_loss(system, target) + total_overshoot * 25000
            reward = -loss

            # if loss > 100:
            #     total_loss = float("nan")
            #     for prev_state, prev_action, _ in scheduled_loss_updates:
            #         qtable[prev_state, prev_action] -= alpha * 100
            #     break

            for i in range(len(scheduled_loss_updates)):
                prev_state, prev_action, accumulated_reward = scheduled_loss_updates[i]
                # accumulated_reward *= pow(0.5,dt)
                accumulated_reward += reward
                scheduled_loss_updates[i] = (prev_state, prev_action, accumulated_reward)
            scheduled_loss_updates.append((state, action, 0.0))
            # Update Q-value using Q-learning formula
            # qtable[current_state, action] += alpha * (reward + gamma * np.max(qtable[next_state]) - qtable[current_state, action])
            if len(scheduled_loss_updates) > 0.2/dt:
                prev_state, prev_action, accumulated_reward = scheduled_loss_updates.pop(0)
                # qtable[prev_state, prev_action] += alpha * (reward + gamma * np.max(qtable[state]) - qtable[prev_state, prev_action])
                qtable[prev_state, prev_action] += alpha * accumulated_reward * dt
                qtable = (
                    qtable 
                    - np.repeat(np.reshape(np.min(qtable,axis=1),[-1,1]),6,axis=1)
                )/(
                    np.repeat(np.reshape(np.max(qtable,axis=1),[-1,1]),6,axis=1)
                    - np.repeat(np.reshape(np.min(qtable,axis=1),[-1,1]),6,axis=1)
                )

            if t[step] > T/2:
                total_loss += loss
        
        losses.append(total_loss/(len(t)/2))
        # Print average loss for each episode
        print(f"Episode: {episode + 1}, Average Loss: {total_loss / (len(t)/2)}")

    return qtable, losses


# Run Q-learning
qtable, losses = q_learning(qtable, episodes=1000)

plt.plot(np.clip(losses,0.0,500.0))
# Out:
# 100 (100,)
# Episode: 1, Average Loss: 12.39274182082436
# 100 (100,)
# Episode: 2, Average Loss: 69.36192890795154
# 100 (100,)
# Episode: 3, Average Loss: 19.693822365165246
# 100 (100,)
# Episode: 4, Average Loss: 6.331349306144585
# 100 (100,)
# Episode: 5, Average Loss: 28.727196097110287
# 100 (100,)
# Episode: 6, Average Loss: 12.814515917602943
# 100 (100,)
# Episode: 7, Average Loss: 48.363314673238676
# 100 (100,)
# Episode: 8, Average Loss: 44.309710156878474
# 100 (100,)
# Episode: 9, Average Loss: 4.408586144380184
# 100 (100,)
# Episode: 10, Average Loss: 67.84337536623052
# 100 (100,)
# Episode: 11, Average Loss: 21.719827293447807
# 100 (100,)
# Episode: 12, Average Loss: 6.9682576849948115
# 100 (100,)
# Episode: 13, Average Loss: 62.60753451402801
# 100 (100,)
# Episode: 14, Average Loss: 5.19227938688797
# 100 (100,)
# Episode: 15, Average Loss: 8.63212743334298
# 100 (100,)
# Episode: 16, Average Loss: 36.68048200515176
# 100 (100,)
# Episode: 17, Average Loss: 22.790703108577972
# 100 (100,)
# Episode: 18, Average Loss: 11.326015633006014
# 100 (100,)
# Episode: 19, Average Loss: 94.06918521217509
# 100 (100,)
# Episode: 20, Average Loss: 20.325607113873723
# 100 (100,)
# Episode: 21, Average Loss: 18.40057741014748
# 100 (100,)
# Episode: 22, Average Loss: 15.962254231774278
# 100 (100,)
# Episode: 23, Average Loss: 72.90860954039124
# 100 (100,)
# Episode: 24, Average Loss: 75.2158543051552
# 100 (100,)
# Episode: 25, Average Loss: 16.53899725359085
# 100 (100,)
# Episode: 26, Average Loss: 60.13766130179205
# 100 (100,)
# Episode: 27, Average Loss: 29.78675181611372
# 100 (100,)
# Episode: 28, Average Loss: 33.7250264946444
# 100 (100,)
# Episode: 29, Average Loss: 11.583676143745247
# 100 (100,)
# Episode: 30, Average Loss: 25.894812831034255
# 100 (100,)
# Episode: 31, Average Loss: 55.744988308910216
# 100 (100,)
# Episode: 32, Average Loss: 10.601986751175835
# 100 (100,)
# Episode: 33, Average Loss: 80.65343116108025
# 100 (100,)
# Episode: 34, Average Loss: 6.689638107080259
# 100 (100,)
# Episode: 35, Average Loss: 38.44606490211399
# 100 (100,)
# Episode: 36, Average Loss: 20.32440818739324
# 100 (100,)
# Episode: 37, Average Loss: 25.497372683148615
# 100 (100,)
# Episode: 38, Average Loss: 7.500206997517758
# 100 (100,)
# Episode: 39, Average Loss: 30.033319078783606
# 100 (100,)
# Episode: 40, Average Loss: 37.547026705029815
# 100 (100,)
# Episode: 41, Average Loss: 21.332156261131203
# 100 (100,)
# Episode: 42, Average Loss: 39.38113997644291
# 100 (100,)
# Episode: 43, Average Loss: 29.804639491048885
# 100 (100,)
# Episode: 44, Average Loss: 25.593308692624692
# 100 (100,)
# Episode: 45, Average Loss: 29.483693758115724
# 100 (100,)
# Episode: 46, Average Loss: 9.76030163931928
# 100 (100,)
# Episode: 47, Average Loss: 34.79022177162606
# 100 (100,)
# Episode: 48, Average Loss: 49.595731910112924
# 100 (100,)
# Episode: 49, Average Loss: 30.21136488691736
# 100 (100,)
# Episode: 50, Average Loss: 14.57035798047595
# 100 (100,)
# Episode: 51, Average Loss: 93.94066837569655
# 100 (100,)
# Episode: 52, Average Loss: 60.077660442967584
# 100 (100,)
# Episode: 53, Average Loss: 10.005602248891757
# 100 (100,)
# Episode: 54, Average Loss: 23.62231212210247
# 100 (100,)
# Episode: 55, Average Loss: 21.935866877939425
# 100 (100,)
# Episode: 56, Average Loss: 4.072730833371851
# 100 (100,)
# Episode: 57, Average Loss: 18.260693489517514
# 100 (100,)
# Episode: 58, Average Loss: 5.36090988227597
# 100 (100,)
# Episode: 59, Average Loss: 11.40741253585315
# 100 (100,)
# Episode: 60, Average Loss: 35.41333066006084
# 100 (100,)
# Episode: 61, Average Loss: 144.16228343594491
# 100 (100,)
# Episode: 62, Average Loss: 28.62460341196322
# 100 (100,)
# Episode: 63, Average Loss: 48.2425884545882
# 100 (100,)
# Episode: 64, Average Loss: 68.22417483769023
# 100 (100,)
# Episode: 65, Average Loss: 21.13052663272016
# 100 (100,)
# Episode: 66, Average Loss: 36.64029080464314
# 100 (100,)
# Episode: 67, Average Loss: 49.3514971937676
# 100 (100,)
# Episode: 68, Average Loss: 45.16842833602307
# 100 (100,)
# Episode: 69, Average Loss: 30.873646249450925
# 100 (100,)
# Episode: 70, Average Loss: 12.160055366432253
# 100 (100,)
# Episode: 71, Average Loss: 19.563217986241348
# 100 (100,)
# Episode: 72, Average Loss: 30.416219702959832
# 100 (100,)
# Episode: 73, Average Loss: 9.452049015324802
# 100 (100,)
# Episode: 74, Average Loss: 8.23898868621843
# 100 (100,)
# Episode: 75, Average Loss: 132.32716383723601
# 100 (100,)
# Episode: 76, Average Loss: 4.888308805431697
# 100 (100,)
# Episode: 77, Average Loss: 145.96884561446174
# 100 (100,)
# Episode: 78, Average Loss: 24.972318613046095
# 100 (100,)
# Episode: 79, Average Loss: 36.52656312704512
# 100 (100,)
# Episode: 80, Average Loss: 18.264454296714653
# 100 (100,)
# Episode: 81, Average Loss: 81.02010309737966
# 100 (100,)
# Episode: 82, Average Loss: 24.51640461220826
# 100 (100,)
# Episode: 83, Average Loss: 38.264998441282295
# 100 (100,)
# Episode: 84, Average Loss: 42.24651793744981
# 100 (100,)
# Episode: 85, Average Loss: 25.38936894672011
# 100 (100,)
# Episode: 86, Average Loss: 25.252388997813185
# 100 (100,)
# Episode: 87, Average Loss: 12.948884753518646
# 100 (100,)
# Episode: 88, Average Loss: 54.64741420135641
# 100 (100,)
# Episode: 89, Average Loss: 54.33652717910403
# 100 (100,)
# Episode: 90, Average Loss: 13.815006803348693
# 100 (100,)
# Episode: 91, Average Loss: 18.200565718423608
# 100 (100,)
# Episode: 92, Average Loss: 105.37101695432129
# 100 (100,)
# Episode: 93, Average Loss: 26.74468482544852
# 100 (100,)
# Episode: 94, Average Loss: 32.4992762795241
# 100 (100,)
# Episode: 95, Average Loss: 27.81601389930578
# 100 (100,)
# Episode: 96, Average Loss: 4.909242056145853
# 100 (100,)
# Episode: 97, Average Loss: 13.914243156578381
# 100 (100,)
# Episode: 98, Average Loss: 10.278108235930832
# 100 (100,)
# Episode: 99, Average Loss: 57.051546978177775
# 100 (100,)
# Episode: 100, Average Loss: 13.803247542065321
# 100 (100,)
# Episode: 101, Average Loss: 25.467631723970737
# 100 (100,)
# Episode: 102, Average Loss: 110.75592463489681
# 100 (100,)
# Episode: 103, Average Loss: 12.342647284846283
# 100 (100,)
# Episode: 104, Average Loss: 35.10527640944201
# 100 (100,)
# Episode: 105, Average Loss: 24.250057648769257
# 100 (100,)
# Episode: 106, Average Loss: 15.163885795369643
# 100 (100,)
# Episode: 107, Average Loss: 54.626859187550544
# 100 (100,)
# Episode: 108, Average Loss: 17.700375416552227
# 100 (100,)
# Episode: 109, Average Loss: 94.39704907674674
# 100 (100,)
# Episode: 110, Average Loss: 59.9338262577778
# 100 (100,)
# Episode: 111, Average Loss: 13.308384776716743
# 100 (100,)
# Episode: 112, Average Loss: 30.806810304214036
# 100 (100,)
# Episode: 113, Average Loss: 28.159970539150713
# 100 (100,)
# Episode: 114, Average Loss: 18.407858729453437
# 100 (100,)
# Episode: 115, Average Loss: 18.345649913169883
# 100 (100,)
# Episode: 116, Average Loss: 29.692531113221673
# 100 (100,)
# Episode: 117, Average Loss: 8.171312106228147
# 100 (100,)
# Episode: 118, Average Loss: 4.492434703617409
# 100 (100,)
# Episode: 119, Average Loss: 67.95294929634227
# 100 (100,)
# Episode: 120, Average Loss: 136.83234626530103
# 100 (100,)
# Episode: 121, Average Loss: 41.76786689560101
# 100 (100,)
# Episode: 122, Average Loss: 252.45098330492962
# 100 (100,)
# Episode: 123, Average Loss: 20.322159706693945
# 100 (100,)
# Episode: 124, Average Loss: 17.21532055062896
# 100 (100,)
# Episode: 125, Average Loss: 49.23769958087315
# 100 (100,)
# Episode: 126, Average Loss: 9.843966552975367
# 100 (100,)
# Episode: 127, Average Loss: 42.081464444951905
# 100 (100,)
# Episode: 128, Average Loss: 43.618294879953
# 100 (100,)
# Episode: 129, Average Loss: 5.94154562867258
# 100 (100,)
# Episode: 130, Average Loss: 6.849923607097061
# 100 (100,)
# Episode: 131, Average Loss: 23.086382464427775
# 100 (100,)
# Episode: 132, Average Loss: 37.68493950647559
# 100 (100,)
# Episode: 133, Average Loss: 52.20778874884958
# 100 (100,)
# Episode: 134, Average Loss: 66.8062587585521
# 100 (100,)
# Episode: 135, Average Loss: 22.663498507328736
# 100 (100,)
# Episode: 136, Average Loss: 44.47424825045575
# 100 (100,)
# Episode: 137, Average Loss: 29.573671059100516
# 100 (100,)
# Episode: 138, Average Loss: 27.71344321695905
# 100 (100,)
# Episode: 139, Average Loss: 22.87647467175306
# 100 (100,)
# Episode: 140, Average Loss: 34.43495522798937
# 100 (100,)
# Episode: 141, Average Loss: 32.670048924463366
# 100 (100,)
# Episode: 142, Average Loss: 35.5861478804404
# 100 (100,)
# Episode: 143, Average Loss: 22.86580192571323
# 100 (100,)
# Episode: 144, Average Loss: 61.53760567384684
# 100 (100,)
# Episode: 145, Average Loss: 22.15759342112113
# 100 (100,)
# Episode: 146, Average Loss: 25.845145970757507
# 100 (100,)
# Episode: 147, Average Loss: 35.244964600470446
# 100 (100,)
# Episode: 148, Average Loss: 40.08063414439915
# 100 (100,)
# Episode: 149, Average Loss: 9.175586279465763
# 100 (100,)
# Episode: 150, Average Loss: 16.51542109045841
# 100 (100,)
# Episode: 151, Average Loss: 25.243922200366605
# 100 (100,)
# Episode: 152, Average Loss: 26.781324985011334
# 100 (100,)
# Episode: 153, Average Loss: 398.15598100013057
# 100 (100,)
# Episode: 154, Average Loss: 64.35599472019173
# 100 (100,)
# Episode: 155, Average Loss: 9.254340993102016
# 100 (100,)
# Episode: 156, Average Loss: 16.47769672923756
# 100 (100,)
# Episode: 157, Average Loss: 100.0211114625753
# 100 (100,)
# Episode: 158, Average Loss: 17.539599325879013
# 100 (100,)
# Episode: 159, Average Loss: 39.77851178530613
# 100 (100,)
# Episode: 160, Average Loss: 60.04176647196781
# 100 (100,)
# Episode: 161, Average Loss: 8.011839301357874
# 100 (100,)
# Episode: 162, Average Loss: 91.39758069389725
# 100 (100,)
# Episode: 163, Average Loss: 15.587474196832948
# 100 (100,)
# Episode: 164, Average Loss: 32.34412736388639
# 100 (100,)
# Episode: 165, Average Loss: 43.774496125221475
# 100 (100,)
# Episode: 166, Average Loss: 72.07751911090531
# 100 (100,)
# Episode: 167, Average Loss: 32.56141753252842
# 100 (100,)
# Episode: 168, Average Loss: 97.37764105666598
# 100 (100,)
# Episode: 169, Average Loss: 15.37396630520912
# 100 (100,)
# Episode: 170, Average Loss: 41.44025873863795
# 100 (100,)
# Episode: 171, Average Loss: 17.773753327719472
# 100 (100,)
# Episode: 172, Average Loss: 40.36325003968684
# 100 (100,)
# Episode: 173, Average Loss: 8.937430574235023
# 100 (100,)
# Episode: 174, Average Loss: 29.76120009942313
# 100 (100,)
# Episode: 175, Average Loss: 223.33471895023393
# 100 (100,)
# Episode: 176, Average Loss: 17.997438365446683
# 100 (100,)
# Episode: 177, Average Loss: 6.114015597085531
# 100 (100,)
# Episode: 178, Average Loss: 20.271630045791234
# 100 (100,)
# Episode: 179, Average Loss: 43.21529575637445
# 100 (100,)
# Episode: 180, Average Loss: 32.239897018487106
# 100 (100,)
# Episode: 181, Average Loss: 21.71742577316235
# 100 (100,)
# Episode: 182, Average Loss: 20.022235273412022
# 100 (100,)
# Episode: 183, Average Loss: 82.7313380275355
# 100 (100,)
# Episode: 184, Average Loss: 47.9050763220793
# 100 (100,)
# Episode: 185, Average Loss: 46.26780696932069
# 100 (100,)
# Episode: 186, Average Loss: 25.610284846239686
# 100 (100,)
# Episode: 187, Average Loss: 9.89515584141937
# 100 (100,)
# Episode: 188, Average Loss: 35.89320250625223
# 100 (100,)
# Episode: 189, Average Loss: 329.0799069748658
# 100 (100,)
# Episode: 190, Average Loss: 11.578912990181868
# 100 (100,)
# Episode: 191, Average Loss: 3.9600270460763443
# 100 (100,)
# Episode: 192, Average Loss: 4.950514925982243
# 100 (100,)
# Episode: 193, Average Loss: 62.666857254217945
# 100 (100,)
# Episode: 194, Average Loss: 50.922224485978816
# 100 (100,)
# Episode: 195, Average Loss: 22.50107097513792
# 100 (100,)
# Episode: 196, Average Loss: 34.33006427750622
# 100 (100,)
# Episode: 197, Average Loss: 7.063341843467216
# 100 (100,)
# Episode: 198, Average Loss: 39.62239008970752
# 100 (100,)
# Episode: 199, Average Loss: 120.93052662184235
# 100 (100,)
# Episode: 200, Average Loss: 24.41656731715158
# 100 (100,)
# Episode: 201, Average Loss: 32.450669833608046
# 100 (100,)
# Episode: 202, Average Loss: 26.388323404544217
# 100 (100,)
# Episode: 203, Average Loss: 29.78702418123739
# 100 (100,)
# Episode: 204, Average Loss: 22.964046695943043
# 100 (100,)
# Episode: 205, Average Loss: 7.842364785211764
# 100 (100,)
# Episode: 206, Average Loss: 11.14398488926726
# 100 (100,)
# Episode: 207, Average Loss: 7.565953821478081
# 100 (100,)
# Episode: 208, Average Loss: 60.289929264200964
# 100 (100,)
# Episode: 209, Average Loss: 93.32340565785125
# 100 (100,)
# Episode: 210, Average Loss: 27.602806123717116
# 100 (100,)
# Episode: 211, Average Loss: 50.70295325833311
# 100 (100,)
# Episode: 212, Average Loss: 71.54347900841648
# 100 (100,)
# Episode: 213, Average Loss: 7.25445640716476
# 100 (100,)
# Episode: 214, Average Loss: 8.646810225475212
# 100 (100,)
# Episode: 215, Average Loss: 3.869802540750758
# 100 (100,)
# Episode: 216, Average Loss: 4.934658187314152
# 100 (100,)
# Episode: 217, Average Loss: 21.87957360928985
# 100 (100,)
# Episode: 218, Average Loss: 15.884983060343886
# 100 (100,)
# Episode: 219, Average Loss: 36.07511957936063
# 100 (100,)
# Episode: 220, Average Loss: 29.203014883124574
# 100 (100,)
# Episode: 221, Average Loss: 88.83394437165327
# 100 (100,)
# Episode: 222, Average Loss: 25.52054952544185
# 100 (100,)
# Episode: 223, Average Loss: 60.90610832054201
# 100 (100,)
# Episode: 224, Average Loss: 73.69754856213603
# 100 (100,)
# Episode: 225, Average Loss: 30.989303216404565
# 100 (100,)
# Episode: 226, Average Loss: 30.813784269787394
# 100 (100,)
# Episode: 227, Average Loss: 16.41826822572242
# 100 (100,)
# Episode: 228, Average Loss: 23.241499175763696
# 100 (100,)
# Episode: 229, Average Loss: 62.15281801647173
# 100 (100,)
# Episode: 230, Average Loss: 8.85541483843765
# 100 (100,)
# Episode: 231, Average Loss: 11.939468624101583
# 100 (100,)
# Episode: 232, Average Loss: 138.06939006848734
# 100 (100,)
# Episode: 233, Average Loss: 13.697545572077054
# 100 (100,)
# Episode: 234, Average Loss: 30.39240982420265
# 100 (100,)
# Episode: 235, Average Loss: 49.987871813154406
# 100 (100,)
# Episode: 236, Average Loss: 15.281816613886283
# 100 (100,)
# Episode: 237, Average Loss: 28.058332932326657
# 100 (100,)
# Episode: 238, Average Loss: 32.4605091133887
# 100 (100,)
# Episode: 239, Average Loss: 107.24045022564046
# 100 (100,)
# Episode: 240, Average Loss: 22.62570397669546
# 100 (100,)
# Episode: 241, Average Loss: 14.399616796411532
# 100 (100,)
# Episode: 242, Average Loss: 3.3720591792577994
# 100 (100,)
# Episode: 243, Average Loss: 40.981157242064256
# 100 (100,)
# Episode: 244, Average Loss: 18.57801221794028
# 100 (100,)
# Episode: 245, Average Loss: 17.161796077135623
# 100 (100,)
# Episode: 246, Average Loss: 132.01817742449742
# 100 (100,)
# Episode: 247, Average Loss: 4.602269192630031
# 100 (100,)
# Episode: 248, Average Loss: 23.59305820713661
# 100 (100,)
# Episode: 249, Average Loss: 14.47734753897836
# 100 (100,)
# Episode: 250, Average Loss: 16.61367509167863
# 100 (100,)
# Episode: 251, Average Loss: 8.049947357242946
# 100 (100,)
# Episode: 252, Average Loss: 5.488173267695759
# 100 (100,)
# Episode: 253, Average Loss: 10.323372119350891
# 100 (100,)
# Episode: 254, Average Loss: 17.081216440834417
# 100 (100,)
# Episode: 255, Average Loss: 14.51950174771652
# 100 (100,)
# Episode: 256, Average Loss: 35.40788415352764
# 100 (100,)
# Episode: 257, Average Loss: 23.352781631385355
# 100 (100,)
# Episode: 258, Average Loss: 39.51337523533451
# 100 (100,)
# Episode: 259, Average Loss: 37.35308207917608
# 100 (100,)
# Episode: 260, Average Loss: 44.552632086587884
# 100 (100,)
# Episode: 261, Average Loss: 32.16779292750612
# 100 (100,)
# Episode: 262, Average Loss: 36.39900957303158
# 100 (100,)
# Episode: 263, Average Loss: 27.086672523031734
# 100 (100,)
# Episode: 264, Average Loss: 2.874328105657851
# 100 (100,)
# Episode: 265, Average Loss: 52.4695555492703
# 100 (100,)
# Episode: 266, Average Loss: 22.607944009575895
# 100 (100,)
# Episode: 267, Average Loss: 13.757775510058288
# 100 (100,)
# Episode: 268, Average Loss: 46.684597457422235
# 100 (100,)
# Episode: 269, Average Loss: 45.255811373602
# 100 (100,)
# Episode: 270, Average Loss: 36.57102740670975
# 100 (100,)
# Episode: 271, Average Loss: 41.12723405526037
# 100 (100,)
# Episode: 272, Average Loss: 30.34032142863768
# 100 (100,)
# Episode: 273, Average Loss: 2.5325450748572704
# 100 (100,)
# Episode: 274, Average Loss: 153.46361439376395
# 100 (100,)
# Episode: 275, Average Loss: 15.341571247584469
# 100 (100,)
# Episode: 276, Average Loss: 11.252256599695226
# 100 (100,)
# Episode: 277, Average Loss: 27.08643162386422
# 100 (100,)
# Episode: 278, Average Loss: 19.904062087490043
# 100 (100,)
# Episode: 279, Average Loss: 13.626788477431248
# 100 (100,)
# Episode: 280, Average Loss: 31.780606665623935
# 100 (100,)
# Episode: 281, Average Loss: 40.13180234020075
# 100 (100,)
# Episode: 282, Average Loss: 294.33330999355417
# 100 (100,)
# Episode: 283, Average Loss: 83.25213744141601
# 100 (100,)
# Episode: 284, Average Loss: 10.395484522301599
# 100 (100,)
# Episode: 285, Average Loss: 82.63246497335638
# 100 (100,)
# Episode: 286, Average Loss: 8.922633495044009
# 100 (100,)
# Episode: 287, Average Loss: 21.66328196297003
# 100 (100,)
# Episode: 288, Average Loss: 25.246749207563113
# 100 (100,)
# Episode: 289, Average Loss: 12.163103379713357
# 100 (100,)
# Episode: 290, Average Loss: 12.798758087561533
# 100 (100,)
# Episode: 291, Average Loss: 5.652542342794463
# 100 (100,)
# Episode: 292, Average Loss: 77.36780290241192
# 100 (100,)
# Episode: 293, Average Loss: 22.958570797978677
# 100 (100,)
# Episode: 294, Average Loss: 15.326685409932297
# 100 (100,)
# Episode: 295, Average Loss: 70.94664096946497
# 100 (100,)
# Episode: 296, Average Loss: 28.712490159575594
# 100 (100,)
# Episode: 297, Average Loss: 6.725791864678296
# 100 (100,)
# Episode: 298, Average Loss: 22.02468750567337
# 100 (100,)
# Episode: 299, Average Loss: 24.025615922088605
# 100 (100,)
# Episode: 300, Average Loss: 15.77454901359183
# 100 (100,)
# Episode: 301, Average Loss: 6.3491662077507325
# 100 (100,)
# Episode: 302, Average Loss: 17.870453370991665
# 100 (100,)
# Episode: 303, Average Loss: 40.64576717628138
# 100 (100,)
# Episode: 304, Average Loss: 30.718309079784095
# 100 (100,)
# Episode: 305, Average Loss: 41.88251401209066
# 100 (100,)
# Episode: 306, Average Loss: 202.9782712925663
# 100 (100,)
# Episode: 307, Average Loss: 22.477881266294684
# 100 (100,)
# Episode: 308, Average Loss: 9.233104664406016
# 100 (100,)
# Episode: 309, Average Loss: 5.833141996548399
# 100 (100,)
# Episode: 310, Average Loss: 24.105495420112767
# 100 (100,)
# Episode: 311, Average Loss: 30.65959413941654
# 100 (100,)
# Episode: 312, Average Loss: 71.60217609317226
# 100 (100,)
# Episode: 313, Average Loss: 39.83706561825424
# 100 (100,)
# Episode: 314, Average Loss: 755.7590567316595
# 100 (100,)
# Episode: 315, Average Loss: 16.832522885751466
# 100 (100,)
# Episode: 316, Average Loss: 17.419558698460797
# 100 (100,)
# Episode: 317, Average Loss: 7.988760679891276
# 100 (100,)
# Episode: 318, Average Loss: 43.41076484412321
# 100 (100,)
# Episode: 319, Average Loss: 3.4598473769527502
# 100 (100,)
# Episode: 320, Average Loss: 27.189591809384513
# 100 (100,)
# Episode: 321, Average Loss: 85.64583669830347
# 100 (100,)
# Episode: 322, Average Loss: 27.065135959016008
# 100 (100,)
# Episode: 323, Average Loss: 18.774534501568017
# 100 (100,)
# Episode: 324, Average Loss: 8.810785266437101
# 100 (100,)
# Episode: 325, Average Loss: 31.36495841940354
# 100 (100,)
# Episode: 326, Average Loss: 34.85877469517564
# 100 (100,)
# Episode: 327, Average Loss: 96.34365094256684
# 100 (100,)
# Episode: 328, Average Loss: 27.43687620574105
# 100 (100,)
# Episode: 329, Average Loss: 18.37460130194813
# 100 (100,)
# Episode: 330, Average Loss: 18.547020146199262
# 100 (100,)
# Episode: 331, Average Loss: 36.89953331227733
# 100 (100,)
# Episode: 332, Average Loss: 82.94741482157912
# 100 (100,)
# Episode: 333, Average Loss: 7.414192003258148
# 100 (100,)
# Episode: 334, Average Loss: 43.151829401429396
# 100 (100,)
# Episode: 335, Average Loss: 27.474125803484185
# 100 (100,)
# Episode: 336, Average Loss: 27.372461504638217
# 100 (100,)
# Episode: 337, Average Loss: 23.08472873754554
# 100 (100,)
# Episode: 338, Average Loss: 89.05135546978987
# 100 (100,)
# Episode: 339, Average Loss: 8.387607735543048
# 100 (100,)
# Episode: 340, Average Loss: 16.11389370453813
# 100 (100,)
# Episode: 341, Average Loss: 5.049729662811723
# 100 (100,)
# Episode: 342, Average Loss: 20.391663961648774
# 100 (100,)
# Episode: 343, Average Loss: 7.920630946901047
# 100 (100,)
# Episode: 344, Average Loss: 105.0005344738088
# 100 (100,)
# Episode: 345, Average Loss: 9.01794495618553
# 100 (100,)
# Episode: 346, Average Loss: 5.030389784331084
# 100 (100,)
# Episode: 347, Average Loss: 55.538781124487265
# 100 (100,)
# Episode: 348, Average Loss: 17.741927762313875
# 100 (100,)
# Episode: 349, Average Loss: 8.0876895500509
# 100 (100,)
# Episode: 350, Average Loss: 64.90816051161632
# 100 (100,)
# Episode: 351, Average Loss: 4.032879003095989
# 100 (100,)
# Episode: 352, Average Loss: 99.53122262062384
# 100 (100,)
# Episode: 353, Average Loss: 29.126770550660854
# 100 (100,)
# Episode: 354, Average Loss: 19.818003348796353
# 100 (100,)
# Episode: 355, Average Loss: 30.412260244375066
# 100 (100,)
# Episode: 356, Average Loss: 193.0667477714243
# 100 (100,)
# Episode: 357, Average Loss: 24.848651314843483
# 100 (100,)
# Episode: 358, Average Loss: 34.86819967966209
# 100 (100,)
# Episode: 359, Average Loss: 13.45988780297027
# 100 (100,)
# Episode: 360, Average Loss: 57.77137244116225
# 100 (100,)
# Episode: 361, Average Loss: 5.6024600846159105
# 100 (100,)
# Episode: 362, Average Loss: 34.64365834743544
# 100 (100,)
# Episode: 363, Average Loss: 21.939297951177206
# 100 (100,)
# Episode: 364, Average Loss: 32.015984766837526
# 100 (100,)
# Episode: 365, Average Loss: 131.7573002127229
# 100 (100,)
# Episode: 366, Average Loss: 34.95843277345096
# 100 (100,)
# Episode: 367, Average Loss: 21.49118945303107
# 100 (100,)
# Episode: 368, Average Loss: 30.791627527248156
# 100 (100,)
# Episode: 369, Average Loss: 4.6344341902675374
# 100 (100,)
# Episode: 370, Average Loss: 58.36125727398055
# 100 (100,)
# Episode: 371, Average Loss: 106.97989085455104
# 100 (100,)
# Episode: 372, Average Loss: 10.838124221988403
# 100 (100,)
# Episode: 373, Average Loss: 13.372046875107214
# 100 (100,)
# Episode: 374, Average Loss: 34.30739930174266
# 100 (100,)
# Episode: 375, Average Loss: 22.938148063435197
# 100 (100,)
# Episode: 376, Average Loss: 234.36258856794495
# 100 (100,)
# Episode: 377, Average Loss: 18.494550927784534
# 100 (100,)
# Episode: 378, Average Loss: 7.967351463466297
# 100 (100,)
# Episode: 379, Average Loss: 82.28009038467886
# 100 (100,)
# Episode: 380, Average Loss: 22.22101003306972
# 100 (100,)
# Episode: 381, Average Loss: 10.512373618987745
# 100 (100,)
# Episode: 382, Average Loss: 24.71919393381066
# 100 (100,)
# Episode: 383, Average Loss: 4.499604472081648
# 100 (100,)
# Episode: 384, Average Loss: 11.287769815084522
# 100 (100,)
# Episode: 385, Average Loss: 6.0081408368011795
# 100 (100,)
# Episode: 386, Average Loss: 61.333812599586025
# 100 (100,)
# Episode: 387, Average Loss: 6.858862743794584
# 100 (100,)
# Episode: 388, Average Loss: 21.665065780422424
# 100 (100,)
# Episode: 389, Average Loss: 6.758666323884385
# 100 (100,)
# Episode: 390, Average Loss: 16.990887562873596
# 100 (100,)
# Episode: 391, Average Loss: 14.849312956650865
# 100 (100,)
# Episode: 392, Average Loss: 19.176640421686667
# 100 (100,)
# Episode: 393, Average Loss: 2.8871056566978974
# 100 (100,)
# Episode: 394, Average Loss: 91.14424673768839
# 100 (100,)
# Episode: 395, Average Loss: 42.44667257029139
# 100 (100,)
# Episode: 396, Average Loss: 21.75889421084504
# 100 (100,)
# Episode: 397, Average Loss: 6.904074086874625
# 100 (100,)
# Episode: 398, Average Loss: 43.72346024825132
# 100 (100,)
# Episode: 399, Average Loss: 9.744829661704696
# 100 (100,)
# Episode: 400, Average Loss: 23.604577486886807
# 100 (100,)
# Episode: 401, Average Loss: 24.589540199554925
# 100 (100,)
# Episode: 402, Average Loss: 15.153910954771352
# 100 (100,)
# Episode: 403, Average Loss: 38.72094418785363
# 100 (100,)
# Episode: 404, Average Loss: 9.614395995511948
# 100 (100,)
# Episode: 405, Average Loss: 39.908076443526824
# 100 (100,)
# Episode: 406, Average Loss: 71.84810935314201
# 100 (100,)
# Episode: 407, Average Loss: 25.371012697416987
# 100 (100,)
# Episode: 408, Average Loss: 6.805853774307304
# 100 (100,)
# Episode: 409, Average Loss: 35.98433300742456
# 100 (100,)
# Episode: 410, Average Loss: 19.01463533094244
# 100 (100,)
# Episode: 411, Average Loss: 125.82306980050672
# 100 (100,)
# Episode: 412, Average Loss: 251.0812271227425
# 100 (100,)
# Episode: 413, Average Loss: 74.91048714608114
# 100 (100,)
# Episode: 414, Average Loss: 32.737858675445516
# 100 (100,)
# Episode: 415, Average Loss: 190.95424371364595
# 100 (100,)
# Episode: 416, Average Loss: 122.3888506458456
# 100 (100,)
# Episode: 417, Average Loss: 748.7124454823823
# 100 (100,)
# Episode: 418, Average Loss: 25.560887130662163
# 100 (100,)
# Episode: 419, Average Loss: 137.00527585420525
# 100 (100,)
# Episode: 420, Average Loss: 8.24166337828471
# 100 (100,)
# Episode: 421, Average Loss: 12.689150093716258
# 100 (100,)
# Episode: 422, Average Loss: 11.046072703880236
# 100 (100,)
# Episode: 423, Average Loss: 8.2999560109981
# 100 (100,)
# Episode: 424, Average Loss: 56.39510205520872
# 100 (100,)
# Episode: 425, Average Loss: 19.82679680632787
# 100 (100,)
# Episode: 426, Average Loss: 4.070696895748097
# 100 (100,)
# Episode: 427, Average Loss: 21.540636678232254
# 100 (100,)
# Episode: 428, Average Loss: 13.373175862681018
# 100 (100,)
# Episode: 429, Average Loss: 7.091065955320364
# 100 (100,)
# Episode: 430, Average Loss: 25.676804802457614
# 100 (100,)
# Episode: 431, Average Loss: 50.79009664112043
# 100 (100,)
# Episode: 432, Average Loss: 57.18899527275363
# 100 (100,)
# Episode: 433, Average Loss: 6.170167396891722
# 100 (100,)
# Episode: 434, Average Loss: 24.46930199428941
# 100 (100,)
# Episode: 435, Average Loss: 29.93972807342703
# 100 (100,)
# Episode: 436, Average Loss: 3.107135923899499
# 100 (100,)
# Episode: 437, Average Loss: 23.594487080520086
# 100 (100,)
# Episode: 438, Average Loss: 39.72708219715783
# 100 (100,)
# Episode: 439, Average Loss: 39.410895638202625
# 100 (100,)
# Episode: 440, Average Loss: 38.576333270753864
# 100 (100,)
# Episode: 441, Average Loss: 72.57803104406898
# 100 (100,)
# Episode: 442, Average Loss: 16.950206393925665
# 100 (100,)
# Episode: 443, Average Loss: 16.47140587465866
# 100 (100,)
# Episode: 444, Average Loss: 21.30068823714636
# 100 (100,)
# Episode: 445, Average Loss: 9.18383693687508
# 100 (100,)
# Episode: 446, Average Loss: 30.506190028256714
# 100 (100,)
# Episode: 447, Average Loss: 14.899863642642996
# 100 (100,)
# Episode: 448, Average Loss: 40.58803280906344
# 100 (100,)
# Episode: 449, Average Loss: 3.2158726326694786
# 100 (100,)
# Episode: 450, Average Loss: 108.75975641185642
# 100 (100,)
# Episode: 451, Average Loss: 78.09319806693324
# 100 (100,)
# Episode: 452, Average Loss: 13.720791813868377
# 100 (100,)
# Episode: 453, Average Loss: 5.837250449154643
# 100 (100,)
# Episode: 454, Average Loss: 5.090586791889732
# 100 (100,)
# Episode: 455, Average Loss: 33.93872941965297
# 100 (100,)
# Episode: 456, Average Loss: 57.20356374179436
# 100 (100,)
# Episode: 457, Average Loss: 115.04823627340626
# 100 (100,)
# Episode: 458, Average Loss: 20.388237538918666
# 100 (100,)
# Episode: 459, Average Loss: 5.9094465971131935
# 100 (100,)
# Episode: 460, Average Loss: 60.260982318202856
# 100 (100,)
# Episode: 461, Average Loss: 21.35548673632405
# 100 (100,)
# Episode: 462, Average Loss: 13.352877505129145
# 100 (100,)
# Episode: 463, Average Loss: 9.807060490400778
# 100 (100,)
# Episode: 464, Average Loss: 9.991360040422586
# 100 (100,)
# Episode: 465, Average Loss: 13.023882877640588
# 100 (100,)
# Episode: 466, Average Loss: 18.25628946661353
# 100 (100,)
# Episode: 467, Average Loss: 30.280446230894285
# 100 (100,)
# Episode: 468, Average Loss: 12.362752758633297
# 100 (100,)
# Episode: 469, Average Loss: 209.58330469502928
# 100 (100,)
# Episode: 470, Average Loss: 24.95321951805504
# 100 (100,)
# Episode: 471, Average Loss: 26.16180115511694
# 100 (100,)
# Episode: 472, Average Loss: 8.621943664716577
# 100 (100,)
# Episode: 473, Average Loss: 30.24958628798012
# 100 (100,)
# Episode: 474, Average Loss: 8.055242262857655
# 100 (100,)
# Episode: 475, Average Loss: 27.174426476304024
# 100 (100,)
# Episode: 476, Average Loss: 17.07287484221434
# 100 (100,)
# Episode: 477, Average Loss: 16.75184165209259
# 100 (100,)
# Episode: 478, Average Loss: 7.227644584277999
# 100 (100,)
# Episode: 479, Average Loss: 4.429278598424965
# 100 (100,)
# Episode: 480, Average Loss: 19.25762028998802
# 100 (100,)
# Episode: 481, Average Loss: 16.908518364073007
# 100 (100,)
# Episode: 482, Average Loss: 52.90088765499538
# 100 (100,)
# Episode: 483, Average Loss: 16.32353427555423
# 100 (100,)
# Episode: 484, Average Loss: 42.09116343844189
# 100 (100,)
# Episode: 485, Average Loss: 20.982522899055525
# 100 (100,)
# Episode: 486, Average Loss: 20.08547030413708
# 100 (100,)
# Episode: 487, Average Loss: 5.58948869448817
# 100 (100,)
# Episode: 488, Average Loss: 6.621937044001279
# 100 (100,)
# Episode: 489, Average Loss: 16.99250366813012
# 100 (100,)
# Episode: 490, Average Loss: 34.730160436933375
# 100 (100,)
# Episode: 491, Average Loss: 14.842804976013019
# 100 (100,)
# Episode: 492, Average Loss: 4.913111548452366
# 100 (100,)
# Episode: 493, Average Loss: 244.73332164663827
# 100 (100,)
# Episode: 494, Average Loss: 31.086528981751457
# 100 (100,)
# Episode: 495, Average Loss: 343.1920127412081
# 100 (100,)
# Episode: 496, Average Loss: 7.9728615826704425
# 100 (100,)
# Episode: 497, Average Loss: 23.159687200766584
# 100 (100,)
# Episode: 498, Average Loss: 5.619916306518961
# 100 (100,)
# Episode: 499, Average Loss: 21.6666591477006
# 100 (100,)
# Episode: 500, Average Loss: 46.05034286001932
# 100 (100,)
# Episode: 501, Average Loss: 18.38638129291981
# 100 (100,)
# Episode: 502, Average Loss: 19.990016751010344
# 100 (100,)
# Episode: 503, Average Loss: 7.865366892714657
# 100 (100,)
# Episode: 504, Average Loss: 8.624751451015127
# 100 (100,)
# Episode: 505, Average Loss: 52.73671209234547
# 100 (100,)
# Episode: 506, Average Loss: 7.912338889852133
# 100 (100,)
# Episode: 507, Average Loss: 20.26705706844014
# 100 (100,)
# Episode: 508, Average Loss: 73.37994139355055
# 100 (100,)
# Episode: 509, Average Loss: 5.20561950996395
# 100 (100,)
# Episode: 510, Average Loss: 40.91350080215748
# 100 (100,)
# Episode: 511, Average Loss: 10.573463282691854
# 100 (100,)
# Episode: 512, Average Loss: 52.106438554120075
# 100 (100,)
# Episode: 513, Average Loss: 43.354171087933665
# 100 (100,)
# Episode: 514, Average Loss: 43.13724274399049
# 100 (100,)
# Episode: 515, Average Loss: 18.24532174082386
# 100 (100,)
# Episode: 516, Average Loss: 6.226777266767223
# 100 (100,)
# Episode: 517, Average Loss: 22.1487773818891
# 100 (100,)
# Episode: 518, Average Loss: 5.778236837497828
# 100 (100,)
# Episode: 519, Average Loss: 23.41632445791212
# 100 (100,)
# Episode: 520, Average Loss: 37.77174502290949
# 100 (100,)
# Episode: 521, Average Loss: 113.26621818728331
# 100 (100,)
# Episode: 522, Average Loss: 11.028354144893974
# 100 (100,)
# Episode: 523, Average Loss: 14.875727214792544
# 100 (100,)
# Episode: 524, Average Loss: 33.28473292394763
# 100 (100,)
# Episode: 525, Average Loss: 6.594935622788634
# 100 (100,)
# Episode: 526, Average Loss: 35.8618249419926
# 100 (100,)
# Episode: 527, Average Loss: 24.802720787431532
# 100 (100,)
# Episode: 528, Average Loss: 34.28718751417925
# 100 (100,)
# Episode: 529, Average Loss: 73.38560008379653
# 100 (100,)
# Episode: 530, Average Loss: 38.201039456423125
# 100 (100,)
# Episode: 531, Average Loss: 36.41780798527635
# 100 (100,)
# Episode: 532, Average Loss: 69.38859615552116
# 100 (100,)
# Episode: 533, Average Loss: 26.940380246387644
# 100 (100,)
# Episode: 534, Average Loss: 45.4906796975148
# 100 (100,)
# Episode: 535, Average Loss: 91.22241055015796
# 100 (100,)
# Episode: 536, Average Loss: 398.16283647759565
# 100 (100,)
# Episode: 537, Average Loss: 88.27016484337078
# 100 (100,)
# Episode: 538, Average Loss: 39.69726702789644
# 100 (100,)
# Episode: 539, Average Loss: 26.94109000158582
# 100 (100,)
# Episode: 540, Average Loss: 32.32555167365251
# 100 (100,)
# Episode: 541, Average Loss: 7.16516074516272
# 100 (100,)
# Episode: 542, Average Loss: 3.0974474294577288
# 100 (100,)
# Episode: 543, Average Loss: 60.15484102998572
# 100 (100,)
# Episode: 544, Average Loss: 13.15047820377843
# 100 (100,)
# Episode: 545, Average Loss: 26.528090621778816
# 100 (100,)
# Episode: 546, Average Loss: 13.724836362029608
# 100 (100,)
# Episode: 547, Average Loss: 77.33844876484291
# 100 (100,)
# Episode: 548, Average Loss: 29.242927288398896
# 100 (100,)
# Episode: 549, Average Loss: 18.940722542517864
# 100 (100,)
# Episode: 550, Average Loss: 12.471158316566465
# 100 (100,)
# Episode: 551, Average Loss: 104.58774311508645
# 100 (100,)
# Episode: 552, Average Loss: 145.16737679351934
# 100 (100,)
# Episode: 553, Average Loss: 37.80412092894247
# 100 (100,)
# Episode: 554, Average Loss: 12.83136376701927
# 100 (100,)
# Episode: 555, Average Loss: 42.51833223224994
# 100 (100,)
# Episode: 556, Average Loss: 9.593242277553427
# 100 (100,)
# Episode: 557, Average Loss: 28.720459444707625
# 100 (100,)
# Episode: 558, Average Loss: 9.60589402943496
# 100 (100,)
# Episode: 559, Average Loss: 42.68385901806383
# 100 (100,)
# Episode: 560, Average Loss: 11.791320493931078
# 100 (100,)
# Episode: 561, Average Loss: 23.789797789915198
# 100 (100,)
# Episode: 562, Average Loss: 34.61765066358153
# 100 (100,)
# Episode: 563, Average Loss: 36.20219802265104
# 100 (100,)
# Episode: 564, Average Loss: 33.539011511838545
# 100 (100,)
# Episode: 565, Average Loss: 19.157141935353888
# 100 (100,)
# Episode: 566, Average Loss: 22.14354706906428
# 100 (100,)
# Episode: 567, Average Loss: 26.851477294833536
# 100 (100,)
# Episode: 568, Average Loss: 55.36765466909986
# 100 (100,)
# Episode: 569, Average Loss: 7.082446061860293
# 100 (100,)
# Episode: 570, Average Loss: 13.062539857239905
# 100 (100,)
# Episode: 571, Average Loss: 50.86779375981352
# 100 (100,)
# Episode: 572, Average Loss: 125.86373954044868
# 100 (100,)
# Episode: 573, Average Loss: 55.776990811899104
# 100 (100,)
# Episode: 574, Average Loss: 17.410203540053217
# 100 (100,)
# Episode: 575, Average Loss: 23.109264629050745
# 100 (100,)
# Episode: 576, Average Loss: 3.7701489816017424
# 100 (100,)
# Episode: 577, Average Loss: 14.72601365336087
# 100 (100,)
# Episode: 578, Average Loss: 39.68930734315819
# 100 (100,)
# Episode: 579, Average Loss: 145.0458751187405
# 100 (100,)
# Episode: 580, Average Loss: 42.39508565298327
# 100 (100,)
# Episode: 581, Average Loss: 69.71057653273397
# 100 (100,)
# Episode: 582, Average Loss: 69.81921965157447
# 100 (100,)
# Episode: 583, Average Loss: 6.928290168175406
# 100 (100,)
# Episode: 584, Average Loss: 18.321035621073126
# 100 (100,)
# Episode: 585, Average Loss: 55.01336182975324
# 100 (100,)
# Episode: 586, Average Loss: 9.198459815877328
# 100 (100,)
# Episode: 587, Average Loss: 62.27638281997639
# 100 (100,)
# Episode: 588, Average Loss: 26.39806383502525
# 100 (100,)
# Episode: 589, Average Loss: 24.55309697218921
# 100 (100,)
# Episode: 590, Average Loss: 146.09906359647536
# 100 (100,)
# Episode: 591, Average Loss: 12.768974484036697
# 100 (100,)
# Episode: 592, Average Loss: 13.646612573592034
# 100 (100,)
# Episode: 593, Average Loss: 9.672787915943466
# 100 (100,)
# Episode: 594, Average Loss: 144.6301354423493
# 100 (100,)
# Episode: 595, Average Loss: 99.20060337959973
# 100 (100,)
# Episode: 596, Average Loss: 11.33858203666643
# 100 (100,)
# Episode: 597, Average Loss: 14.478219038111888
# 100 (100,)
# Episode: 598, Average Loss: 10.470379528954776
# 100 (100,)
# Episode: 599, Average Loss: 31.1608058886352
# 100 (100,)
# Episode: 600, Average Loss: 8.724993784695256
# 100 (100,)
# Episode: 601, Average Loss: 17.225834951977593
# 100 (100,)
# Episode: 602, Average Loss: 13.97664441017422
# 100 (100,)
# Episode: 603, Average Loss: 12.52776725624094
# 100 (100,)
# Episode: 604, Average Loss: 19.007007220707326
# 100 (100,)
# Episode: 605, Average Loss: 5.950484498294418
# 100 (100,)
# Episode: 606, Average Loss: 17.291628754944558
# 100 (100,)
# Episode: 607, Average Loss: 14.001985266747106
# 100 (100,)
# Episode: 608, Average Loss: 13.702111544362744
# 100 (100,)
# Episode: 609, Average Loss: 13.179320525680184
# 100 (100,)
# Episode: 610, Average Loss: 49.89791287534119
# 100 (100,)
# Episode: 611, Average Loss: 158.55553831864907
# 100 (100,)
# Episode: 612, Average Loss: 7.60569861963184
# 100 (100,)
# Episode: 613, Average Loss: 16.551502227598675
# 100 (100,)
# Episode: 614, Average Loss: 12.200738806077206
# 100 (100,)
# Episode: 615, Average Loss: 41.8615330387299
# 100 (100,)
# Episode: 616, Average Loss: 5.187131058281142
# 100 (100,)
# Episode: 617, Average Loss: 29.820739090073776
# 100 (100,)
# Episode: 618, Average Loss: 5.973655209433462
# 100 (100,)
# Episode: 619, Average Loss: 56.976861177233694
# 100 (100,)
# Episode: 620, Average Loss: 21.366271139786235
# 100 (100,)
# Episode: 621, Average Loss: 9.467589539755243
# 100 (100,)
# Episode: 622, Average Loss: 30.8299960970329
# 100 (100,)
# Episode: 623, Average Loss: 10.078421087875576
# 100 (100,)
# Episode: 624, Average Loss: 49.85137926509883
# 100 (100,)
# Episode: 625, Average Loss: 31.305448514277742
# 100 (100,)
# Episode: 626, Average Loss: 19.873129294351827
# 100 (100,)
# Episode: 627, Average Loss: 10.353238179804203
# 100 (100,)
# Episode: 628, Average Loss: 20.98956874162673
# 100 (100,)
# Episode: 629, Average Loss: 51.81179749214577
# 100 (100,)
# Episode: 630, Average Loss: 69.23449196139984
# 100 (100,)
# Episode: 631, Average Loss: 3.2310372835015846
# 100 (100,)
# Episode: 632, Average Loss: 23.92034486044484
# 100 (100,)
# Episode: 633, Average Loss: 55.190160478365385
# 100 (100,)
# Episode: 634, Average Loss: 17.945149103833508
# 100 (100,)
# Episode: 635, Average Loss: 65.23016518830553
# 100 (100,)
# Episode: 636, Average Loss: 21.010913279373128
# 100 (100,)
# Episode: 637, Average Loss: 5.379450543513317
# 100 (100,)
# Episode: 638, Average Loss: 31.771814319454215
# 100 (100,)
# Episode: 639, Average Loss: 9.832912709847314
# 100 (100,)
# Episode: 640, Average Loss: 16.248877306981978
# 100 (100,)
# Episode: 641, Average Loss: 18.89262650241883
# 100 (100,)
# Episode: 642, Average Loss: 20.247761641179437
# 100 (100,)
# Episode: 643, Average Loss: 3.398188672435213
# 100 (100,)
# Episode: 644, Average Loss: 13.441701906596496
# 100 (100,)
# Episode: 645, Average Loss: 60.207059712981255
# 100 (100,)
# Episode: 646, Average Loss: 21.11949257978394
# 100 (100,)
# Episode: 647, Average Loss: 37.19399156531425
# 100 (100,)
# Episode: 648, Average Loss: 14.71297802049995
# 100 (100,)
# Episode: 649, Average Loss: 4.536338357004677
# 100 (100,)
# Episode: 650, Average Loss: 42.834698434914856
# 100 (100,)
# Episode: 651, Average Loss: 61.46678836747531
# 100 (100,)
# Episode: 652, Average Loss: 35.71419611067127
# 100 (100,)
# Episode: 653, Average Loss: 20.949379401156225
# 100 (100,)
# Episode: 654, Average Loss: 37.93778150462027
# 100 (100,)
# Episode: 655, Average Loss: 11.220935035323992
# 100 (100,)
# Episode: 656, Average Loss: 10.023731860449606
# 100 (100,)
# Episode: 657, Average Loss: 13.20755956138967
# 100 (100,)
# Episode: 658, Average Loss: 15.141119544217581
# 100 (100,)
# Episode: 659, Average Loss: 10.318951605631979
# 100 (100,)
# Episode: 660, Average Loss: 25.544138904189218
# 100 (100,)
# Episode: 661, Average Loss: 24.65345910953978
# 100 (100,)
# Episode: 662, Average Loss: 19.449918395674292
# 100 (100,)
# Episode: 663, Average Loss: 24.9516381467529
# 100 (100,)
# Episode: 664, Average Loss: 42.41648981105273
# 100 (100,)
# Episode: 665, Average Loss: 37.673542558636015
# 100 (100,)
# Episode: 666, Average Loss: 17.971194031880337
# 100 (100,)
# Episode: 667, Average Loss: 4.474664405768232
# 100 (100,)
# Episode: 668, Average Loss: 14.418289369780348
# 100 (100,)
# Episode: 669, Average Loss: 52.01287374030893
# 100 (100,)
# Episode: 670, Average Loss: 4.173976806065227
# 100 (100,)
# Episode: 671, Average Loss: 5.598263819435285
# 100 (100,)
# Episode: 672, Average Loss: 22.106350884277973
# 100 (100,)
# Episode: 673, Average Loss: 20.952599016070895
# 100 (100,)
# Episode: 674, Average Loss: 14.70209455168615
# 100 (100,)
# Episode: 675, Average Loss: 19.474098658226772
# 100 (100,)
# Episode: 676, Average Loss: 58.081509621048454
# 100 (100,)
# Episode: 677, Average Loss: 102.8707111502751
# 100 (100,)
# Episode: 678, Average Loss: 32.9996682527473
# 100 (100,)
# Episode: 679, Average Loss: 21.378259250628066
# 100 (100,)
# Episode: 680, Average Loss: 38.27393461857947
# 100 (100,)
# Episode: 681, Average Loss: 12.944007419103286
# 100 (100,)
# Episode: 682, Average Loss: 40.83300588742674
# 100 (100,)
# Episode: 683, Average Loss: 36.25664304096719
# 100 (100,)
# Episode: 684, Average Loss: 5.332491752515547
# 100 (100,)
# Episode: 685, Average Loss: 29.731605801775242
# 100 (100,)
# Episode: 686, Average Loss: 9.906030709186929
# 100 (100,)
# Episode: 687, Average Loss: 38.34711776372148
# 100 (100,)
# Episode: 688, Average Loss: 2.9569569996595653
# 100 (100,)
# Episode: 689, Average Loss: 31.91647431122603
# 100 (100,)
# Episode: 690, Average Loss: 11.621153108310386
# 100 (100,)
# Episode: 691, Average Loss: 39.238642543777615
# 100 (100,)
# Episode: 692, Average Loss: 126.3274436298112
# 100 (100,)
# Episode: 693, Average Loss: 33.63918339282513
# 100 (100,)
# Episode: 694, Average Loss: 28.652321451964177
# 100 (100,)
# Episode: 695, Average Loss: 42.32253248006613
# 100 (100,)
# Episode: 696, Average Loss: 51.28495316734614
# 100 (100,)
# Episode: 697, Average Loss: 58.01280134743874
# 100 (100,)
# Episode: 698, Average Loss: 5.665250881363815
# 100 (100,)
# Episode: 699, Average Loss: 130.40195048018742
# 100 (100,)
# Episode: 700, Average Loss: 210.56105851500357
# 100 (100,)
# Episode: 701, Average Loss: 6.3925956341828085
# 100 (100,)
# Episode: 702, Average Loss: 34.3691468560866
# 100 (100,)
# Episode: 703, Average Loss: 7.848736882917875
# 100 (100,)
# Episode: 704, Average Loss: 31.500689863958378
# 100 (100,)
# Episode: 705, Average Loss: 18.392354370974243
# 100 (100,)
# Episode: 706, Average Loss: 10.393899086027723
# 100 (100,)
# Episode: 707, Average Loss: 15.78697021777269
# 100 (100,)
# Episode: 708, Average Loss: 58.55856908507609
# 100 (100,)
# Episode: 709, Average Loss: 76.27250916905807
# 100 (100,)
# Episode: 710, Average Loss: 9.907259836645183
# 100 (100,)
# Episode: 711, Average Loss: 69.46966269204178
# 100 (100,)
# Episode: 712, Average Loss: 14.966423062583527
# 100 (100,)
# Episode: 713, Average Loss: 141.05647804096182
# 100 (100,)
# Episode: 714, Average Loss: 20.70213098951948
# 100 (100,)
# Episode: 715, Average Loss: 37.935003312127954
# 100 (100,)
# Episode: 716, Average Loss: 27.38651409945517
# 100 (100,)
# Episode: 717, Average Loss: 10.59410269038981
# 100 (100,)
# Episode: 718, Average Loss: 27.170874232079097
# 100 (100,)
# Episode: 719, Average Loss: 29.732999493542387
# 100 (100,)
# Episode: 720, Average Loss: 15.20973519610662
# 100 (100,)
# Episode: 721, Average Loss: 3.0628040922179958
# 100 (100,)
# Episode: 722, Average Loss: 252.14408307754752
# 100 (100,)
# Episode: 723, Average Loss: 31.721828269475342
# 100 (100,)
# Episode: 724, Average Loss: 63.07686689261832
# 100 (100,)
# Episode: 725, Average Loss: 27.008875865845933
# 100 (100,)
# Episode: 726, Average Loss: 42.31709349478988
# 100 (100,)
# Episode: 727, Average Loss: 25.830810374439054
# 100 (100,)
# Episode: 728, Average Loss: 7.806607642775114
# 100 (100,)
# Episode: 729, Average Loss: 15.491807011347051
# 100 (100,)
# Episode: 730, Average Loss: 11.026375987485302
# 100 (100,)
# Episode: 731, Average Loss: 14.434475699746939
# 100 (100,)
# Episode: 732, Average Loss: 41.04555295351244
# 100 (100,)
# Episode: 733, Average Loss: 6.215878398408005
# 100 (100,)
# Episode: 734, Average Loss: 52.557792261492615
# 100 (100,)
# Episode: 735, Average Loss: 28.939885478445827
# 100 (100,)
# Episode: 736, Average Loss: 3.8506894635269906
# 100 (100,)
# Episode: 737, Average Loss: 39.15456450946043
# 100 (100,)
# Episode: 738, Average Loss: 17.099529682594977
# 100 (100,)
# Episode: 739, Average Loss: 69.33849664298505
# 100 (100,)
# Episode: 740, Average Loss: 41.549873702103106
# 100 (100,)
# Episode: 741, Average Loss: 22.024274244833464
# 100 (100,)
# Episode: 742, Average Loss: 10.209575827083873
# 100 (100,)
# Episode: 743, Average Loss: 6.095748684521862
# 100 (100,)
# Episode: 744, Average Loss: 37.230501716333904
# 100 (100,)
# Episode: 745, Average Loss: 31.143128623444678
# 100 (100,)
# Episode: 746, Average Loss: 33.89298570909708
# 100 (100,)
# Episode: 747, Average Loss: 14.860968355854164
# 100 (100,)
# Episode: 748, Average Loss: 20.414935623901975
# 100 (100,)
# Episode: 749, Average Loss: 78.69684072495156
# 100 (100,)
# Episode: 750, Average Loss: 20.999446888182096
# 100 (100,)
# Episode: 751, Average Loss: 44.21433122548501
# 100 (100,)
# Episode: 752, Average Loss: 2.804506549262967
# 100 (100,)
# Episode: 753, Average Loss: 117.99412004737437
# 100 (100,)
# Episode: 754, Average Loss: 38.68483285446118
# 100 (100,)
# Episode: 755, Average Loss: 44.487334981706574
# 100 (100,)
# Episode: 756, Average Loss: 11.475288900748623
# 100 (100,)
# Episode: 757, Average Loss: 70.43076749976822
# 100 (100,)
# Episode: 758, Average Loss: 5.302951594848349
# 100 (100,)
# Episode: 759, Average Loss: 13.293465078880542
# 100 (100,)
# Episode: 760, Average Loss: 5.705064193642837
# 100 (100,)
# Episode: 761, Average Loss: 36.220777506500355
# 100 (100,)
# Episode: 762, Average Loss: 47.51751660871233
# 100 (100,)
# Episode: 763, Average Loss: 13.707940062976773
# 100 (100,)
# Episode: 764, Average Loss: 495.70981146027486
# 100 (100,)
# Episode: 765, Average Loss: 403.2124704938708
# 100 (100,)
# Episode: 766, Average Loss: 109.80973441233367
# 100 (100,)
# Episode: 767, Average Loss: 17.080638049605028
# 100 (100,)
# Episode: 768, Average Loss: 39.552455969166026
# 100 (100,)
# Episode: 769, Average Loss: 18.077774416519837
# 100 (100,)
# Episode: 770, Average Loss: 89.88702743809284
# 100 (100,)
# Episode: 771, Average Loss: 3.112386935056674
# 100 (100,)
# Episode: 772, Average Loss: 30.622063710878944
# 100 (100,)
# Episode: 773, Average Loss: 31.19992324192794
# 100 (100,)
# Episode: 774, Average Loss: 29.141934606092804
# 100 (100,)
# Episode: 775, Average Loss: 29.26556320731197
# 100 (100,)
# Episode: 776, Average Loss: 18.875162146683582
# 100 (100,)
# Episode: 777, Average Loss: 22.74256502270701
# 100 (100,)
# Episode: 778, Average Loss: 22.56492341363846
# 100 (100,)
# Episode: 779, Average Loss: 19.810012001083802
# 100 (100,)
# Episode: 780, Average Loss: 15.450750461412362
# 100 (100,)
# Episode: 781, Average Loss: 52.91412602418896
# 100 (100,)
# Episode: 782, Average Loss: 73.14046752828514
# 100 (100,)
# Episode: 783, Average Loss: 9.655805118595207
# 100 (100,)
# Episode: 784, Average Loss: 91.04431587983898
# 100 (100,)
# Episode: 785, Average Loss: 9.765073992405194
# 100 (100,)
# Episode: 786, Average Loss: 34.26312955529517
# 100 (100,)
# Episode: 787, Average Loss: 37.85172513544612
# 100 (100,)
# Episode: 788, Average Loss: 151.36613634600934
# 100 (100,)
# Episode: 789, Average Loss: 6.443502586627712
# 100 (100,)
# Episode: 790, Average Loss: 4.637205032170381
# 100 (100,)
# Episode: 791, Average Loss: 9.894203552749303
# 100 (100,)
# Episode: 792, Average Loss: 19.354326369900388
# 100 (100,)
# Episode: 793, Average Loss: 17.38149501450046
# 100 (100,)
# Episode: 794, Average Loss: 3.836730878387827
# 100 (100,)
# Episode: 795, Average Loss: 67.51117451318618
# 100 (100,)
# Episode: 796, Average Loss: 27.039561828839084
# 100 (100,)
# Episode: 797, Average Loss: 26.98943356383613
# 100 (100,)
# Episode: 798, Average Loss: 38.93073683899652
# 100 (100,)
# Episode: 799, Average Loss: 36.98814515573181
# 100 (100,)
# Episode: 800, Average Loss: 10.04486914206151
# 100 (100,)
# Episode: 801, Average Loss: 10.930231259148913
# 100 (100,)
# Episode: 802, Average Loss: 12.987049802449707
# 100 (100,)
# Episode: 803, Average Loss: 27.850819246180667
# 100 (100,)
# Episode: 804, Average Loss: 10.069688308311378
# 100 (100,)
# Episode: 805, Average Loss: 46.866865990413146
# 100 (100,)
# Episode: 806, Average Loss: 6.819729860030409
# 100 (100,)
# Episode: 807, Average Loss: 20.086265023123374
# 100 (100,)
# Episode: 808, Average Loss: 10.383690093725917
# 100 (100,)
# Episode: 809, Average Loss: 21.117068898735983
# 100 (100,)
# Episode: 810, Average Loss: 21.1320546580668
# 100 (100,)
# Episode: 811, Average Loss: 42.22047868994713
# 100 (100,)
# Episode: 812, Average Loss: 4.15381605241941
# 100 (100,)
# Episode: 813, Average Loss: 34.609730613216385
# 100 (100,)
# Episode: 814, Average Loss: 54.51972165066217
# 100 (100,)
# Episode: 815, Average Loss: 26.318590290531098
# 100 (100,)
# Episode: 816, Average Loss: 3.3939349160307213
# 100 (100,)
# Episode: 817, Average Loss: 9.184554392147904
# 100 (100,)
# Episode: 818, Average Loss: 6.101370002242085
# 100 (100,)
# Episode: 819, Average Loss: 33.703961644494775
# 100 (100,)
# Episode: 820, Average Loss: 114.98041578820863
# 100 (100,)
# Episode: 821, Average Loss: 15.166294191880832
# 100 (100,)
# Episode: 822, Average Loss: 7.295322192142078
# 100 (100,)
# Episode: 823, Average Loss: 52.833102297375284
# 100 (100,)
# Episode: 824, Average Loss: 14.98730747954422
# 100 (100,)
# Episode: 825, Average Loss: 43.17882144415636
# 100 (100,)
# Episode: 826, Average Loss: 7.724794378656161
# 100 (100,)
# Episode: 827, Average Loss: 12.550729918068848
# 100 (100,)
# Episode: 828, Average Loss: 4.632429784343422
# 100 (100,)
# Episode: 829, Average Loss: 24.165466310925975
# 100 (100,)
# Episode: 830, Average Loss: 45.32798090310267
# 100 (100,)
# Episode: 831, Average Loss: 36.51487082930921
# 100 (100,)
# Episode: 832, Average Loss: 24.3871311993878
# 100 (100,)
# Episode: 833, Average Loss: 115.429842875498
# 100 (100,)
# Episode: 834, Average Loss: 74.38443109077434
# 100 (100,)
# Episode: 835, Average Loss: 23.41352079363536
# 100 (100,)
# Episode: 836, Average Loss: 48.5774989744633
# 100 (100,)
# Episode: 837, Average Loss: 27.66196622340603
# 100 (100,)
# Episode: 838, Average Loss: 16.156876809634547
# 100 (100,)
# Episode: 839, Average Loss: 9.600975659441996
# 100 (100,)
# Episode: 840, Average Loss: 22.385391281585303
# 100 (100,)
# Episode: 841, Average Loss: 54.410368108357424
# 100 (100,)
# Episode: 842, Average Loss: 19.51648807172903
# 100 (100,)
# Episode: 843, Average Loss: 12.341305029089296
# 100 (100,)
# Episode: 844, Average Loss: 53.88402689045043
# 100 (100,)
# Episode: 845, Average Loss: 6.119658509177628
# 100 (100,)
# Episode: 846, Average Loss: 64.044048747442
# 100 (100,)
# Episode: 847, Average Loss: 43.99834156046082
# 100 (100,)
# Episode: 848, Average Loss: 13.02132909380933
# 100 (100,)
# Episode: 849, Average Loss: 5.878126779549523
# 100 (100,)
# Episode: 850, Average Loss: 6.348386694493806
# 100 (100,)
# Episode: 851, Average Loss: 60.997898277920186
# 100 (100,)
# Episode: 852, Average Loss: 26.56071180372076
# 100 (100,)
# Episode: 853, Average Loss: 34.45895699540769
# 100 (100,)
# Episode: 854, Average Loss: 40.13049157175656
# 100 (100,)
# Episode: 855, Average Loss: 22.397704741241295
# 100 (100,)
# Episode: 856, Average Loss: 25.93158222122437
# 100 (100,)
# Episode: 857, Average Loss: 26.9894620520937
# 100 (100,)
# Episode: 858, Average Loss: 15.808297805103543
# 100 (100,)
# Episode: 859, Average Loss: 16.06949918293817
# 100 (100,)
# Episode: 860, Average Loss: 11.144035946936851
# 100 (100,)
# Episode: 861, Average Loss: 35.55754627168856
# 100 (100,)
# Episode: 862, Average Loss: 28.765508911043856
# 100 (100,)
# Episode: 863, Average Loss: 10.217133928483612
# 100 (100,)
# Episode: 864, Average Loss: 117.05747788853522
# 100 (100,)
# Episode: 865, Average Loss: 71.32894274928728
# 100 (100,)
# Episode: 866, Average Loss: 25.36783298759125
# 100 (100,)
# Episode: 867, Average Loss: 6.456786532298846
# 100 (100,)
# Episode: 868, Average Loss: 27.104191567804065
# 100 (100,)
# Episode: 869, Average Loss: 47.099042274626896
# 100 (100,)
# Episode: 870, Average Loss: 18.36062472868665
# 100 (100,)
# Episode: 871, Average Loss: 64.43538741129086
# 100 (100,)
# Episode: 872, Average Loss: 3.0588666043340784
# 100 (100,)
# Episode: 873, Average Loss: 11.054248061220608
# 100 (100,)
# Episode: 874, Average Loss: 24.402339481415407
# 100 (100,)
# Episode: 875, Average Loss: 3.014441751940986
# 100 (100,)
# Episode: 876, Average Loss: 16.168090877623214
# 100 (100,)
# Episode: 877, Average Loss: 11.381526672383796
# 100 (100,)
# Episode: 878, Average Loss: 2.530236321702685
# 100 (100,)
# Episode: 879, Average Loss: 5.85974605942909
# 100 (100,)
# Episode: 880, Average Loss: 56.34251289658314
# 100 (100,)
# Episode: 881, Average Loss: 74.69248555922843
# 100 (100,)
# Episode: 882, Average Loss: 22.81573071755312
# 100 (100,)
# Episode: 883, Average Loss: 32.15419310261262
# 100 (100,)
# Episode: 884, Average Loss: 18.82299092382756
# 100 (100,)
# Episode: 885, Average Loss: 23.39137424999888
# 100 (100,)
# Episode: 886, Average Loss: 95.49348685756564
# 100 (100,)
# Episode: 887, Average Loss: 78.82573661387045
# 100 (100,)
# Episode: 888, Average Loss: 12.992019071119914
# 100 (100,)
# Episode: 889, Average Loss: 34.606740912354006
# 100 (100,)
# Episode: 890, Average Loss: 24.727721595779215
# 100 (100,)
# Episode: 891, Average Loss: 21.680868609268646
# 100 (100,)
# Episode: 892, Average Loss: 21.457591314674442
# 100 (100,)
# Episode: 893, Average Loss: 43.70184493125912
# 100 (100,)
# Episode: 894, Average Loss: 31.824376594868927
# 100 (100,)
# Episode: 895, Average Loss: 323.97648406594925
# 100 (100,)
# Episode: 896, Average Loss: 3.8222691327181675
# 100 (100,)
# Episode: 897, Average Loss: 15.348334127745936
# 100 (100,)
# Episode: 898, Average Loss: 829.7178275284925
# 100 (100,)
# Episode: 899, Average Loss: 99.66049526526248
# 100 (100,)
# Episode: 900, Average Loss: 35.06436255760033
# 100 (100,)
# Episode: 901, Average Loss: 93.77137924740296
# 100 (100,)
# Episode: 902, Average Loss: 27.990806424201327
# 100 (100,)
# Episode: 903, Average Loss: 7.343608882099186
# 100 (100,)
# Episode: 904, Average Loss: 5.816607599240587
# 100 (100,)
# Episode: 905, Average Loss: 19.744816812944798
# 100 (100,)
# Episode: 906, Average Loss: 44.63587301805949
# 100 (100,)
# Episode: 907, Average Loss: 353.8056098151218
# 100 (100,)
# Episode: 908, Average Loss: 5.643808542689388
# 100 (100,)
# Episode: 909, Average Loss: 23.76430521398352
# 100 (100,)
# Episode: 910, Average Loss: 25.071470114269985
# 100 (100,)
# Episode: 911, Average Loss: 11.91917008419644
# 100 (100,)
# Episode: 912, Average Loss: 320.2869339107809
# 100 (100,)
# Episode: 913, Average Loss: 227.20731064060857
# 100 (100,)
# Episode: 914, Average Loss: 15.149698826177369
# 100 (100,)
# Episode: 915, Average Loss: 69.5637001120695
# 100 (100,)
# Episode: 916, Average Loss: 16.528450047953466
# 100 (100,)
# Episode: 917, Average Loss: 27.66146373911245
# 100 (100,)
# Episode: 918, Average Loss: 18.507073626299572
# 100 (100,)
# Episode: 919, Average Loss: 37.794076851555694
# 100 (100,)
# Episode: 920, Average Loss: 77.53163082634073
# 100 (100,)
# Episode: 921, Average Loss: 23.24186787585893
# 100 (100,)
# Episode: 922, Average Loss: 21.996317642873727
# 100 (100,)
# Episode: 923, Average Loss: 9.941282795854471
# 100 (100,)
# Episode: 924, Average Loss: 77.34326953401064
# 100 (100,)
# Episode: 925, Average Loss: 14.490963194808696
# 100 (100,)
# Episode: 926, Average Loss: 25.508753690493187
# 100 (100,)
# Episode: 927, Average Loss: 8.217860966960055
# 100 (100,)
# Episode: 928, Average Loss: 14.012118088191112
# 100 (100,)
# Episode: 929, Average Loss: 70.78704248770995
# 100 (100,)
# Episode: 930, Average Loss: 25.74861045414991
# 100 (100,)
# Episode: 931, Average Loss: 47.58565840204511
# 100 (100,)
# Episode: 932, Average Loss: 21.04064284933934
# 100 (100,)
# Episode: 933, Average Loss: 23.124871949490345
# 100 (100,)
# Episode: 934, Average Loss: 5.165138214847802
# 100 (100,)
# Episode: 935, Average Loss: 21.64391098137524
# 100 (100,)
# Episode: 936, Average Loss: 6.459792349995791
# 100 (100,)
# Episode: 937, Average Loss: 48.71651877970219
# 100 (100,)
# Episode: 938, Average Loss: 13.037876570870274
# 100 (100,)
# Episode: 939, Average Loss: 58.47908070563495
# 100 (100,)
# Episode: 940, Average Loss: 66.28527894241675
# 100 (100,)
# Episode: 941, Average Loss: 42.885601284865906
# 100 (100,)
# Episode: 942, Average Loss: 83.82087687270646
# 100 (100,)
# Episode: 943, Average Loss: 3.2134506559443796
# 100 (100,)
# Episode: 944, Average Loss: 59.781384258128675
# 100 (100,)
# Episode: 945, Average Loss: 27.215494236141737
# 100 (100,)
# Episode: 946, Average Loss: 7.841775014458185
# 100 (100,)
# Episode: 947, Average Loss: 62.025045640643775
# 100 (100,)
# Episode: 948, Average Loss: 28.426500881442024
# 100 (100,)
# Episode: 949, Average Loss: 26.175249957980245
# 100 (100,)
# Episode: 950, Average Loss: 14.476502572206135
# 100 (100,)
# Episode: 951, Average Loss: 4.699610726711745
# 100 (100,)
# Episode: 952, Average Loss: 38.12368479768711
# 100 (100,)
# Episode: 953, Average Loss: 26.862135272950596
# 100 (100,)
# Episode: 954, Average Loss: 13.586279516392175
# 100 (100,)
# Episode: 955, Average Loss: 12.09616923184122
# 100 (100,)
# Episode: 956, Average Loss: 8.951167668694914
# 100 (100,)
# Episode: 957, Average Loss: 3.3753806376478366
# 100 (100,)
# Episode: 958, Average Loss: 25.191711391556385
# 100 (100,)
# Episode: 959, Average Loss: 115.20339406544132
# 100 (100,)
# Episode: 960, Average Loss: 22.168145035232957
# 100 (100,)
# Episode: 961, Average Loss: 27.023716847703184
# 100 (100,)
# Episode: 962, Average Loss: 16.55417709025892
# 100 (100,)
# Episode: 963, Average Loss: 24.354489902516203
# 100 (100,)
# Episode: 964, Average Loss: 21.979929890977427
# 100 (100,)
# Episode: 965, Average Loss: 17.003240900575907
# 100 (100,)
# Episode: 966, Average Loss: 18.310977322302932
# 100 (100,)
# Episode: 967, Average Loss: 40.11613755108316
# 100 (100,)
# Episode: 968, Average Loss: 32.226112759510436
# 100 (100,)
# Episode: 969, Average Loss: 4.662522257033413
# 100 (100,)
# Episode: 970, Average Loss: 10.54309409310102
# 100 (100,)
# Episode: 971, Average Loss: 27.765610791341892
# 100 (100,)
# Episode: 972, Average Loss: 26.95771563297507
# 100 (100,)
# Episode: 973, Average Loss: 21.97444887426558
# 100 (100,)
# Episode: 974, Average Loss: 35.36564552254069
# 100 (100,)
# Episode: 975, Average Loss: 15.015066751945177
# 100 (100,)
# Episode: 976, Average Loss: 78.88344598607323
# 100 (100,)
# Episode: 977, Average Loss: 28.964276990944448
# 100 (100,)
# Episode: 978, Average Loss: 25.560872973576075
# 100 (100,)
# Episode: 979, Average Loss: 64.7686052148207
# 100 (100,)
# Episode: 980, Average Loss: 3.917006458817011
# 100 (100,)
# Episode: 981, Average Loss: 5.1297710517518995
# 100 (100,)
# Episode: 982, Average Loss: 37.55668217105617
# 100 (100,)
# Episode: 983, Average Loss: 14.266707384743745
# 100 (100,)
# Episode: 984, Average Loss: 91.48795625888988
# 100 (100,)
# Episode: 985, Average Loss: 362.60945751387464
# 100 (100,)
# Episode: 986, Average Loss: 8.216448078209764
# 100 (100,)
# Episode: 987, Average Loss: 9.029031191831594
# 100 (100,)
# Episode: 988, Average Loss: 26.818522233595726
# 100 (100,)
# Episode: 989, Average Loss: 157.75553181261964
# 100 (100,)
# Episode: 990, Average Loss: 31.901781058617857
# 100 (100,)
# Episode: 991, Average Loss: 25.890694341311455
# 100 (100,)
# Episode: 992, Average Loss: 6.416304787690072
# 100 (100,)
# Episode: 993, Average Loss: 32.75608653205176
# 100 (100,)
# Episode: 994, Average Loss: 13.530538652017697
# 100 (100,)
# Episode: 995, Average Loss: 13.07404688108364
# 100 (100,)
# Episode: 996, Average Loss: 15.910768442191955
# 100 (100,)
# Episode: 997, Average Loss: 18.24521875195803
# 100 (100,)
# Episode: 998, Average Loss: 15.199402838604668
# 100 (100,)
# Episode: 999, Average Loss: 91.3146146425379
# 100 (100,)
# Episode: 1000, Average Loss: 38.13658414551471

# %%
qta = np.argmax(qtable, axis=1)
# Q-learning function
def q_run(system: TheSystem, pid: PIDController, qtable: npt.NDArray, path: tuple[float, npt.NDArray, npt.NDArray]):
    # Generate a path and reset the system
    dt, t, x = path

    xs = []
    kps = []
    kis = []
    kds = []

    for step in range(t.shape[0]):
        target = (x[step],(x[step]-x[max(0,step-1)])/dt)
        power = pid.control(system.x, target[0], dt)
        # Get the current state

        # Update PID parameters based on the chosen action
        update_pid_by_action(pid, qta[get_state(system, target, power)], dt)
        # pid.kp = np.clip(pid.kp, 0.0, 2.0)
        # pid.ki = np.clip(pid.ki, 0.0, 2.0)
        # pid.kd = np.clip(pid.kd, 0.0, 2.0)

        # Perform the action and get the next state
        system.step(dt, 10.0*np.clip(power,-5.0,5.0))
        system.v = np.clip(system.v, -5.0,5.0)

        xs.append(system.x)

        kps.append(pid.kp)
        kis.append(pid.ki)
        kds.append(pid.kd)



    return t, np.array(xs), np.array(kps), np.array(kis), np.array(kds)


_, tt, path1, = gen_path(90.0,0.01)
_, _, path2, = gen_path(90.0,0.01)
_, _, path3, = gen_path(90.0,0.01)
t = np.linspace(0.0, 2.0, int(90.0/0.01))
path = (0.01, tt, 
        np.clip(2.0 - 4*t, 0.0,1.0) * path1
        + np.clip(3*t-2.0, 0.0,1.0) * path2
 #path1 * np.clip(2.0 - t/ 20.0,0.0,1.0))
        )

# t,x,kps,kis,kds = q_run(TheSystem(10.0,0.004,0.01),PIDController(np.random.uniform(0.1, 0.9),np.random.uniform(0.1, 0.9),np.random.uniform(0.1, 0.9)),qtable,path)
t,x,kps,kis,kds = q_run(TheSystem(10.0,0.01,0.01),PIDController(0.0,0.0,0.0),qtable,path)
plt.plot(t,x)
plt.plot(t,path[2],"--")
# plt.plot(t,kps,":")
# plt.plot(t,kis,":")
# plt.plot(t,kds,":")

plt.legend(["x","tx","kp","ki","kd"])

# %%
np.argmax(qtable, axis=1)
# Out:
# array([3, 3, 2, 1, 4, 0, 2, 3, 4, 4, 4, 3, 4, 4, 2, 4, 4, 3, 3],
#       dtype=int64)
